# %% [markdown]
# # scrape top 100 Songs from website

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

url = "https://www.billboard.com/charts/hot-100/"

response = requests.get(url)
response.raise_for_status()

soup = BeautifulSoup(response.text, "html.parser")

# Function to clean invisible characters
def clean_text(text):
    text = text.strip()  # remove leading/trailing whitespace
    text = re.sub(r'\s+', ' ', text)  # replace multiple whitespace/newlines/tabs with single space
    return text

# ---- H3 TITLE CLASSES ----
h3_classes = [
    "c-title",
    "a-font-basic",
    "u-letter-spacing-0010",
    "u-max-width-397",
    "lrv-u-font-size-16",
    "u-line-height-22px",
    "u-word-spacing-0063",
    "a-truncate-ellipsis-2line",
    "lrv-u-margin-b-025",
]

h3_selector = "h3." + ".".join(h3_classes)
song_names = [clean_text(item.get_text()) for item in soup.select(h3_selector)]

# ---- SPAN ARTIST CLASSES ----
span_classes = [
    "c-label",
    "a-no-trucate",
    "a-font-secondary",
    "u-font-size-15",
    "u-letter-spacing-0010",
    "u-line-height-21px",
    "a-children-link-color-black",
    "lrv-u-display-block",
    "a-truncate-ellipsis-2line",
    "u-max-width-397",
]

span_selector = "span." + ".".join(span_classes)
artist_names = [clean_text(item.get_text()) for item in soup.select(span_selector)]

# ---- Create DataFrame ----
min_len = min(len(song_names), len(artist_names))
df = pd.DataFrame({
    "song_title": song_names[:min_len],
    "artist_name": artist_names[:min_len]
})



print(df)
# Out:
#                            song_title  \
# 0     All I Want For Christmas Is You
# 1                      Last Christmas
# 2   Rockin' Around The Christmas Tree
# 3                    Jingle Bell Rock
# 4                              Golden
# ..                                ...
# 95                           For Good
# 96                       No Good Deed
# 97         Let Alone The One You Love
# 98             The Life Of A Showgirl
# 99              When Did You Get Hot?
#
#                                  artist_name
# 0                               Mariah Carey
# 1                                      Wham!
# 2                                 Brenda Lee
# 3                                Bobby Helms
# 4       HUNTR/X: EJAE, Audrey Nuna & REI AMI
# ..                                       ...
# 95             Cynthia Erivo & Ariana Grande
# 96                             Cynthia Erivo
# 97                               Olivia Dean
# 98  Taylor Swift Featuring Sabrina Carpenter
# 99                         Sabrina Carpenter
#
# [100 rows x 2 columns]

# %% [markdown]
# # get the track IDs for every song

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials
import config

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))


track_ids = []

# Loop through each row in the DataFrame
for index, row in df.iterrows():
    query = f"{row['song_title']} by {row['artist_name']}"
    results = sp.search(q=query, limit=1, market="GB")
    print("query", query)

    # Check if a track is found
    if results['tracks']['items']:
        track_id = results['tracks']['items'][0]['id']
    else:
        track_id = None  # If no track found
    print("track_id", track_id)
    track_ids.append(track_id)

# Add track IDs to the DataFrame
df['track_id'] = track_ids
# Out:
# query All I Want For Christmas Is You by Mariah Carey
# track_id 1dsU1IcJ4MTZXeApbwuu4B
# query Last Christmas by Wham!
# track_id 3KaotdNHy44p4Ah9Yt0yKb
# query Rockin' Around The Christmas Tree by Brenda Lee
# track_id 0zr8GA2HroEZ1mtncgW3xI
# query Jingle Bell Rock by Bobby Helms
# track_id 5u54rqcQl2UYJgTyNLuTHv
# query Golden by HUNTR/X: EJAE, Audrey Nuna & REI AMI
# track_id 5tVnzVWIKrmmuOPGbXUbT4
# query The Fate Of Ophelia by Taylor Swift
# track_id 1dosSsKwYF7hoQA2kuu6wI
# query Ordinary by Alex Warren
# track_id 6qqrTXSdwiJaq8SO0X2lSe
# query Santa Tell Me by Ariana Grande
# track_id 26yZeDdPKAnPQrmxaXoqk3
# query The Christmas Song (Merry Christmas To You) by Nat "King" Cole
# track_id 4PK1GubWVTmaOi4Og0Phr4
# query It's The Most Wonderful Time Of The Year by Andy Williams
# track_id 4zSvqMbMKsyEVuiKXMY44O
# query Underneath The Tree by Kelly Clarkson
# track_id 45GY7KeQBmWgXvTlU6zFkU
# query Man I Need by Olivia Dean
# track_id 1qbmS6ep2hbBRaEZFpn7BX
# query Let It Snow! Let It Snow! Let It Snow! by Dean Martin
# track_id 4kKdvXD0ez7jp1296JmAts
# query It's Beginning To Look A Lot Like Christmas by Michael Buble
# track_id 3QHUcfZy3Eag1QghcsjqBV
# query Sleigh Ride by The Ronettes
# track_id 5wcL95EGLqxVkMNpVnLFG0
# query A Holly Jolly Christmas by Burl Ives
# track_id 6w9CbiWGhelGoOtr3Xr143
# query Feliz Navidad by Jose Feliciano
# track_id 2Qxl1GRAv2UZYqJhm2nzVl
# query Christmas (Baby Please Come Home) by Darlene Love
# track_id 3PIDciSFdrQxSQSihim3hN
# query White Christmas (1947) by Bing Crosby With Ken Darby Singers & John Scott Trotter & His Orchestra
# track_id 3XsaSIPWvM61RIFfeb0BBR
# query Mutt by Leon Thomas
# track_id 1CtRHG4oPa1iOQKLnORJKF
# query Jingle Bells by Frank Sinatra With The Orchestra & Chorus Of Gordon Jenkins
# track_id 4KV9bM7a1KDc7b7OakFZic
# query Run Rudolph Run by Chuck Berry
# track_id 2I1isoOkVXBEYLE11uEJYk
# query Back To Friends by sombr
# track_id 7K1m0WlCzG8xZlLuBvgfQ6
# query It's Beginning To Look A Lot Like Christmas by Perry Como And The Fontane Sisters With Mitchell Ayres And His Orchestra
# track_id 2pXpURmn6zC5ZYDMms6fwa
# query Opalite by Taylor Swift
# track_id 67osB3wmJVTFzKhWqPb1Hm
# query Folded by Kehlani
# track_id 0bxPRWprUVpQK0UFcddkrA
# query Choosin' Texas by Ella Langley
# track_id 3F8SPDKxic0gaRpLI2wIuO
# query Daisies by Justin Bieber
# track_id 6JX6NGKuehv0DpJh2uTe4C
# query Deck The Halls by Nat King Cole
# track_id 1RrvUX8CDT45rDqI82bu9t
# query Santa Baby by Eartha Kitt With Henri Rene And His Orchestra
# track_id 1foCxQtxBweJtZmdxhEHVO
# query Blue Christmas by Elvis Presley
# track_id 2AcJuiRry0NtHJSFyKzRCM
# query Here Comes Santa Claus (Right Down Santa Claus Lane) by Gene Autry
# track_id 25leEEaz1gIpp7o21Fqyjo
# query Wonderful Christmastime by Paul McCartney
# track_id 5eY1g1gDmY49SUooFPsOpa
# query Please Come Home For Christmas by Eagles
# track_id 6BXcZ4bcVoAwrYiH8excaR
# query Like It's Christmas by Jonas Brothers
# track_id 6faHyZRv6wFTg9C2NqqxpY
# query Holly Jolly Christmas by Michael Buble
# track_id 7BQ40mY3YZCGld8uQBuDGY
# query Rudolph The Red-Nosed Reindeer by Gene Autry & The Pinafores
# track_id 47otoIkhx3fkdivEXL5OB6
# query Christmastime Is Here by Vince Guaraldi Trio
# track_id 3bMfUUpzUzqWp9II00yRhE
# query Little Saint Nick by The Beach Boys
# track_id 1lKnOKidDub7ysBguWpAgX
# query Santa, Can't You Hear Me by Kelly Clarkson & Ariana Grande
# track_id 38lBDJu9AKcBDXpId9ySQg
# query You're A Mean One, Mr. Grinch by Thurl Ravenscroft
# track_id 0cNWIhVUtIhZT1QNz9BhmE
# query It Depends by Chris Brown Featuring Bryson Tiller
# track_id 5JrQ1Jc3udCcAJasEpH0Ov
# query Merry Christmas by Ed Sheeran & Elton John
# track_id 3ET9Szai5f5ryGB0tPrRqS
# query Mistletoe by Justin Bieber
# track_id 7xapw9Oy21WpfEcib2ErSA
# query Tit For Tat by Tate McRae
# track_id 3As52VFFtHoYPhdUNPT0BW
# query Santa Claus Is Comin' To Town by Jackson 5
# track_id 0ReKGhOuNFt2KyVbTffKLM
# query So Easy (To Fall In Love) by Olivia Dean
# track_id 6sGIMrtIzQjdzNndVxe397
# query Baby It's Cold Outside by Dean Martin
# track_id 6dgTZ6JwHKViVANRqajQ5Z
# query Winter Wonderland by Darlene Love
# track_id 7kE6btERrlSIJt5kbkB1RY
# query This Christmas by Donny Hathaway
# track_id 6Oci9lCUoM9ybUq54bVMqM
# query Tears by Sabrina Carpenter
# track_id 5BXgoZuocyJJqujHtN6zFc
# query Don't Mind If I Do by Riley Green Featuring Ella Langley
# track_id 1FHIZknONrV2c20w0x5AVG
# query Where Is My Husband! by RAYE
# track_id 1lNeLQh7BDM7KvYTteYV4M
# query wgft by Gunna Featuring Burna Boy
# track_id 4e0kTsdTX7ewvyYg06BGGV
# query Gabriela by KATSEYE
# track_id 3w2BGmiu9gMYrTHChGLQtx
# query Happen To Me by Russell Dickerson
# track_id 5zdUc1JRCImBYcDWgvFNpE
# query 20 Cigarettes by Morgan Wallen
# track_id 5dK0aA2pLca6h9ANFTTMQf
# query Nice To Meet You by Myles Smith
# track_id 6KhQwU9hh3ucIF48b5Kzr8
# query 6 Months Later by Megan Moroney
# track_id 6GTQGUEhuIIJDWRnXSu3kI
# query Is It A Crime by Mariah The Scientist & Kali Uchis
# track_id 27WUApENu4rsjBsYfb10gI
# query Yukon by Justin Bieber
# track_id 2q806mixyBFn36DmCHdVwW
# query Hell At Night by BigXthaPlug Featuring Ella Langley
# track_id 5mxVKAuunOKqcBfR5ivbRf
# query House Again by Hudson Westbrook
# track_id 6jio30tUpk9Q5WpBVfIs11
# query Better Me For You (Brown Eyes) by Max McNown
# track_id 5N54GyvfhQdg4ydYYyeaDL
# query A Couple Minutes by Olivia Dean
# track_id 6KBJyJ38tvpzjWqMeV3MAl
# query Nobody's Girl by Tate McRae
# track_id 5MNUJ1AZXMjU7FUE9aQ2Ym
# query Shot Callin by YoungBoy Never Broke Again
# track_id 4XCzFaUl0CvaOYC5GLCRIS
# query Elizabeth Taylor by Taylor Swift
# track_id 1A2vZKJZovt4828jwLgiB3
# query 3,2,1 by Tucker Wetmore
# track_id 1gJeOuF6VuBy2jZNN8CIOP
# query Dracula by Tame Impala
# track_id 7bhMeTchpDsG69wNmAZgzN
# query Take Me Thru Dere by Metro Boomin, Quavo, Breskii & YKNIECE
# track_id 2GFawZaMjG8QLxiR4OD3db
# query The Fall by Cody Johnson
# track_id 4dS1QQw8askb1KSDLCKuvK
# query Travelin' Soldier by Cody Johnson
# track_id 0my7bw84UcX256xTi73HOs
# query Sugar On My Tongue by Tyler, The Creator
# track_id 2YC1fWEjVru8p7dB5eGIfK
# query 12 To 12 by sombr
# track_id 6jWxXfUH8yumRp4DAxuhNm
# query Darlin' by Chase Matthew
# track_id 0rt1wmavCMj8lU1TFkP1e6
# query Amen by Shaboozey & Jelly Roll
# track_id 2qg0Rpiq1FsbbRzlui2aQG
# query Last One To Know by Gavin Adcock
# track_id 4JAmBKnHyq2avqNvJ81Mao
# query Favorite Country Song by HARDY
# track_id 3roJNjr7zRlLyr1bTPq0AS
# query Father Figure by Taylor Swift
# track_id 1lD0oPIfSYid1LhPvgrz10
# query Camera by Ed Sheeran
# track_id 6ZezzrpfyuxgsNdttWXEOk
# query ErrTime by Cardi B
# track_id 2s2RplGcKgNgMGwRXIWGNH
# query Back In The Saddle by Luke Combs
# track_id 5zjKxcNJ3v0IkJcOQHWQRZ
# query Wi$h Li$t by Taylor Swift
# track_id 3Qeh4z08FfDBRfQMfDv83f
# query Cowgirl by Parmalee
# track_id 0Zy9VEBhwZzh3RPzMDvdrM
# query Shake The Snow Globe by Gwen Stefani
# track_id 3uqinR4FCjLv28bkrTdNX5
# query Days Like These by Luke Combs
# track_id 11oAwZq3NfZxDgJuqvw4jJ
# query Anything But Love by Tate McRae
# track_id 5qDKA8TgdRLaDb71oICbua
# query What Kinda Man by Parker McCollum
# track_id 23fK6OKpqOXPcUI3nRpfNa
# query How Far Does A Goodbye Go by Jason Aldean
# track_id 17U2M7HB14yGe9QSAmbyyB
# query Nice To Each Other by Olivia Dean
# track_id 2cMpwtX4deyONoqBAfzcAp
# query Gone Gone Gone by David Guetta, Teddy Swims & Tones And I
# track_id 6e1FpexOjC5Tx3Ij7UusJv
# query The Dead Dance by Lady Gaga
# track_id 7DKnaQhA2aO40rZMhEG2KO
# query Went Legit by G Herbo
# track_id 6j9hMjMCp0II1QX1auUlWX
# query Sienna by The Marias
# track_id 0InIeZW4P6VO7dUGRM4AKH
# query For Good by Cynthia Erivo & Ariana Grande
# track_id 0NSQes0wj8vkwNnnAAKu6E
# query No Good Deed by Cynthia Erivo
# track_id 2y0K02q8rtU3poqylCjT7X
# query Let Alone The One You Love by Olivia Dean
# track_id 1mMRddLLTQgjxVmgXQOYhT
# query The Life Of A Showgirl by Taylor Swift Featuring Sabrina Carpenter
# track_id 5CHOrwxKLXkY1XVZauxvnw
# query When Did You Get Hot? by Sabrina Carpenter
# track_id 69mFkztzbPcoL89iqeuhdv

# %% [markdown]
# # save to CSV

# %%
df.to_csv("trending_songs.csv", index=False)
